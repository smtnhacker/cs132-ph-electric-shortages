# %%
from datetime import datetime
import unicodedata
import ast
import emoji
import pandas as pd
import re

def normalize_line(line: str):
    try:
        string = ast.literal_eval(line).decode()
    except Exception:
        string = ''
    no_endline = string.replace('\n', ' ')
    no_unicode_letters = unicodedata.normalize('NFKC', no_endline)
    no_emoji = emoji.replace_emoji(no_unicode_letters, replace='')

    return no_emoji

def try_regex(reg, string, todo):
    res = reg.findall(string)
    if len(res) > 0:
        try:
            return todo(res[0])
        except Exception as e:
            print(res, e)
            return False
    return False

def process_aleco_file(file_path):
    data = { 'date': [], 'location': [], 'type': [] }
    df = pd.DataFrame(data)
    
    date_regex = re.compile("DATE: .*\, 202.")
    location_regex = re.compile("SUBSTATION: .* REASON")
    location_regex2 = re.compile("SUBSTATION: .*  REASON")
    location_regex3 = re.compile("SUBSTATION: .* DATE")
    location_regex4 = re.compile("SUBSTATION: .*  DATE")
    try:
        with open(file_path, 'r') as f:
            for line in f:
                normalized = normalize_line(line)
                if 'POWER INTERRUPTION' not in normalized: continue
                    
                try:
                    date_str = try_regex(date_regex, normalized, lambda x: x[6:])
                    if not date_str:
                        date_str = try_regex(re.compile("DATE: .* 202."), normalized, lambda x: x[6:])
                    if not date_str:
                        date_str = try_regex(re.compile("DATE:.* 202."), normalized, lambda x: x[5:])
                    if not date_str:
                        date_str = try_regex(re.compile("Date: .* 202."), normalized, lambda x: x[6:])
                    if not date_str:
                        date_str = try_regex(re.compile("Date:.* 202."), normalized, lambda x: x[5:])
                    
                    print(date_str)
                    date = datetime.strptime(date_str, "%B %d, %Y")
                except Exception as e:
                    print(f"Error getting date from {normalized}: {e}")
                    print("---", date_str)
                    
                try:
                    location_str = try_regex(location_regex, normalized, lambda x: x[12:-6])
                    if not location_str:
                        location_str = try_regex(location_regex2, normalized, lambda x: x[12:-6])
                        
                    if not location_str:
                        location_str = try_regex(location_regex3, normalized, lambda x: x[12:-5])
                    
                    if not location_str:
                        location_str = try_regex(location_regex4, normalized, lambda x: x[12:-5])
                        
                    if not location_str:
                        location_str = try_regex("Substation: .*  DATE", normalized, lambda x: x[12:-5])
                    
                    location = location_str
                    
                    type = 'ALECO'
                    row_df = pd.DataFrame([[date, location, type]], columns=df.columns)
                    df = pd.concat([row_df, df], ignore_index=True)
                except Exception as e:
                    print(f"Error getting location from {normalized}: {e}")
                    print("---", location_str)
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        
    return df

# %%
res = process_aleco_file('ALECO_public_5.txt')
res.to_csv('data.csv', index=False, header=False, mode='a')
# Out:
# MARCH 12, 2024
# March 10, 2024
# March 09, 2024
# March 08, 2024
# March 7, 2024
# March 8, 2024
# Error getting location from NGCP POWER INTERRUPTION ​ Substation: WASHINGTON SUBSTATION, BITANO SUBSTATION AND STA. MISERICORDIA SUBSTATION Date: March 8, 2024 Time: 5:00 AM - 5:00 PM Reason: • To facilitate erection and installation of new steel poles SP-02 and SP-05 under SLSUP Stage 2 Project - Daraga SS.: 'str' object has no attribute 'findall'
# --- False
# March 05, 2024
# March 05, 2024
# March 4, 2024
# March 4, 2024
# March 04, 2024
# March 03, 2024
# March 03, 2024
# March 02, 2024
# March 02, 2024
# March 02, 2024
# March 6, 2024
# Error getting location from NGCP POWER INTERRUPTION ​ Substation: WASHINGTON SUBSTATION, BITANO SUBSTATION AND STA. MISERICORDIA SUBSTATION Date: March 6, 2024 Time: 5:00 AM - 5:00 PM Reason: • To facilitate erection and installation of new steel poles SP-02 and SP-05 under SLSUP Stage 2 Project - Daraga SS.: 'str' object has no attribute 'findall'
# --- False
# FEBRUARY 29, 2024
# NGCP POWER INTERRUPTION  Power service interruption scheduled February 29, 2024 (0700H - 1900H) and March 2, 2024 (1630H - 1700H) will be shortened to February 29, 2024 (0830H - 0900H).  Details:  Substation: TABACO & MALINAO SUBSTATION Date: February 29, 2024
# Error getting date from UPDATE: NGCP POWER INTERRUPTION  Power service interruption scheduled February 29, 2024 (0700H - 1900H) and March 2, 2024 (1630H - 1700H) will be shortened to February 29, 2024 (0830H - 0900H).  Details:  Substation: TABACO & MALINAO SUBSTATION Date: February 29, 2024 Time: 8:30 AM - 9:00 AM Reason: • Momentary shutdown of Ligao-Pawa 69 kV Line to isolate Cale ADS.: time data 'NGCP POWER INTERRUPTION  Power service interruption scheduled February 29, 2024 (0700H - 1900H) and March 2, 2024 (1630H - 1700H) will be shortened to February 29, 2024 (0830H - 0900H).  Details:  Substation: TABACO & MALINAO SUBSTATION Date: February 29, 2024' does not match format '%B %d, %Y'
# --- NGCP POWER INTERRUPTION  Power service interruption scheduled February 29, 2024 (0700H - 1900H) and March 2, 2024 (1630H - 1700H) will be shortened to February 29, 2024 (0830H - 0900H).  Details:  Substation: TABACO & MALINAO SUBSTATION Date: February 29, 2024
# Error getting location from UPDATE: NGCP POWER INTERRUPTION  Power service interruption scheduled February 29, 2024 (0700H - 1900H) and March 2, 2024 (1630H - 1700H) will be shortened to February 29, 2024 (0830H - 0900H).  Details:  Substation: TABACO & MALINAO SUBSTATION Date: February 29, 2024 Time: 8:30 AM - 9:00 AM Reason: • Momentary shutdown of Ligao-Pawa 69 kV Line to isolate Cale ADS.: 'str' object has no attribute 'findall'
# --- False
# FEBRUARY 28, 2024
# FEBRUARY 27, 2024
# FEBRUARY 26, 2024
# February 29, 2024 Time: 7:00 AM - 7:00 PM Reason: • Tapping and energization of the new Tiwi C-Malinao 69 kV Line as part of the Tiwi Substation Upgrading Project and transfer of power source from Daraga to Tiwi Substation.  Date: March 2, 2024
# Error getting date from NGCP POWER INTERRUPTION ​ Substation: TABACO & MALINAO SUBSTATION Date: February 29, 2024 Time: 7:00 AM - 7:00 PM Reason: • Tapping and energization of the new Tiwi C-Malinao 69 kV Line as part of the Tiwi Substation Upgrading Project and transfer of power source from Daraga to Tiwi Substation.  Date: March 2, 2024 Time: 4:30 PM - 5:00 PM Reason: • Transfer of power source from Tiwi to Daraga Substation as requested by APRI: unconverted data remains:  Time: 7:00 AM - 7:00 PM Reason: • Tapping and energization of the new Tiwi C-Malinao 69 kV Line as part of the Tiwi Substation Upgrading Project and transfer of power source from Daraga to Tiwi Substation.  Date: March 2, 2024
# --- February 29, 2024 Time: 7:00 AM - 7:00 PM Reason: • Tapping and energization of the new Tiwi C-Malinao 69 kV Line as part of the Tiwi Substation Upgrading Project and transfer of power source from Daraga to Tiwi Substation.  Date: March 2, 2024
# Error getting location from NGCP POWER INTERRUPTION ​ Substation: TABACO & MALINAO SUBSTATION Date: February 29, 2024 Time: 7:00 AM - 7:00 PM Reason: • Tapping and energization of the new Tiwi C-Malinao 69 kV Line as part of the Tiwi Substation Upgrading Project and transfer of power source from Daraga to Tiwi Substation.  Date: March 2, 2024 Time: 4:30 PM - 5:00 PM Reason: • Transfer of power source from Tiwi to Daraga Substation as requested by APRI: 'str' object has no attribute 'findall'
# --- False
# FEBRUARY 26, 2024
# FEBRUARY 27, 2024
# FEBRUARY 25, 2024
# FEBRUARY 23, 2024
# FEBRUARY 23, 2024
# FEBRUARY 22, 2024
# FEBRUARY 22, 2024
# FEBRUARY 19, 2024
# FEBRUARY 20, 2024
# FEBRUARY 17, 2024
# FEBRUARY 17, 2024
# February 17, 2024
# FEBRUARY 16, 2024
# February 24, 2024
# Error getting location from NGCP POWER INTERRUPTION ​ Substation: POLANGUI SUBSTATION Date: February 24, 2024 Time: 6:00 AM - 7:00 AM / 5:00 PM - 6:00 PM Reason: • 6:00 AM - 7:00 AM - Momentary power interruption to isolate and conduct preventive maintenance along Ligao-Polangui section. • 5:00 PM - 6:00 PM - Momentary power interruption to reconnect Ligao-Polangui section.: 'str' object has no attribute 'findall'
# --- False
# FEBRUARY 13, 2024
# False
# Error getting date from NGCP POWER INTERRUPTION ​ Substation: WASHINGTON SUBSTATION Affected Area: Sitio Bugit, Purok 1 Brgy. Anislag, Daraga, Baldo Subdivision, Brgy. Anislag, Daraga Time: 6:00 AM - 6:00 PM Reason: • To ensure the safety of NGCP line crew conducting replacement of Overhead Ground Wire (OHGW): strptime() argument 1 must be str, not bool
# --- False
# Error getting location from NGCP POWER INTERRUPTION ​ Substation: WASHINGTON SUBSTATION Affected Area: Sitio Bugit, Purok 1 Brgy. Anislag, Daraga, Baldo Subdivision, Brgy. Anislag, Daraga Time: 6:00 AM - 6:00 PM Reason: • To ensure the safety of NGCP line crew conducting replacement of Overhead Ground Wire (OHGW): 'str' object has no attribute 'findall'
# --- False
# FEBRUARY 8, 2024
# FEBRUARY 07, 2024
# February 10, 2024
# Error getting location from NGCP POWER INTERRUPTION ​ Substation: LIGAO SUBSTATION - ALL FEEDERS                     TABACO SUBSTATION - ALL FEEDERS                     MALINAO SUBSTATION - ALL FEEDERS Date: February 10, 2024 (Saturday) Time: 6:00 AM - 6:00 PM Reason: • Preventive maintenance and testing of secondary devices. • General maintenance and testing of HVE. • Testing of LA at Dunao (near 69kV DS). • Preventive / Corrective maintenance along the line (TL Group) • Replacement of meter box at Ligao T1 and T2 Metering points (MASM Group) • Hotspot correction on outgoing DS and CT of Daraga - Ligao 69 kV line.: 'str' object has no attribute 'findall'
# --- False
# FEBRUARY 02, 2024
# February 6, 2024
# Error getting location from NGCP POWER INTERRUPTION ​ Substation
 2023
# Error getting location from NGCP POWER INTERRUPTION ​ Substation:WASHINGTON SUBSTATION - ALL FEEDERS         BITANO SUBSTATION - ALL FEEDERS Date: December 15, 2023 (Friday) Reason: • 12 MN - 2:00 AM - Isolation and reconnection of ALECO Washington load-end Substation Re: Hotspot correction at 69 kV SF6 line side  • 12 MN - 12:30 AM / 1:30 AM - 2:00 AM - Momentary shutdown of Daraga Leagzpi 69 kv line to facilitate isolation/reconnection of ALECO Washington Load-end Substation: 'str' object has no attribute 'findall'
# --- False
# DECEMBER 12, 2023
# DECEMBER 12, 2023
# December 10, 2023
# DECEMBER 09, 2023
# December 09, 2023
# DECEMBER 08, 2023
# DECEMBER 08, 2023
# DECEMBER 08, 2023
# December 10, 2023
# Error getting location from NGCP POWER INTERRUPTION ​ Substation: Ligao Substation - All Feeders          Tabaco Substation - All Feeders          Malinao Substation - All Feeders Date: December 10, 2023 (SUNDAY) Time: ​6:00 AM - 6:00 PM Reason: Preventive maintenance along the line; Correction of line defects: 'str' object has no attribute 'findall'
# --- False
# DECEMBER 04, 2023
# DECEMBER 03, 2023
# DECEMBER 03, 2023
# DECEMBER 01, 2023
# December 9, 2023
# Error getting location from NGCP POWER INTERRUPTION ​ Substation: Polangui Substation - All Feeders Date: December 9, 2023 (SATURDAY) Time: ​6:00 AM - 6:00 PM Reason: Correction of line defects; Installation of ABS along the line; Replacement of defective insulators along the line; Reinforcement of Iriga LES 69kV VT & LA drop conductors.: 'str' object has no attribute 'findall'
# --- False
# December 1, 2023
# Error getting location from NGCP POWER INTERRUPTION ​ Substation: Sto. Misericordia Substation - All Feeders Date: December 1, 2023 (FRIDAY) Time: ​6:00 AM - 12:00 NN Reason: Preventive maintenance and testing of associated secondary feeder protection.: 'str' object has no attribute 'findall'
# --- False
# December 1, 2023
# NOVEMBER 29, 2023
# NOVEMBER 28, 2023
# NOVEMBER 26, 2023
# NOVEMBER 25, 2023
# November 25, 2023
# December 2, 2023
# Error getting location from NGCP POWER INTERRUPTION ​ Substation: Tabaco Substation - All Feeders              Malinao Substation - All Feeders Date: December 2, 2023 (SATURDAY) Time: ​6:00 AM - 6:00 PM Reason: To conduct line and substation maintenance activities: 'str' object has no attribute 'findall'
# --- False
# NOVEMBER 22, 2023
# NOVEMBER 20, 2023
# November 24, 2023
# November 22, 2023
# NOVEMBER 20, 2023
# NOVEMBER 20, 2023
# NOVEMBER 19, 2023
# NOVEMBER 20, 2023
# NOVEMBER 19, 2023
# NOVEMBER 20, 2023
# NOVEMBER 19, 2023
# NOVEMBER 20, 2023
# NOVEMBER 19, 2023
# NOVEMBER 20, 2023
# NOVEMBER 19, 2023
# NOVEMBER 20, 2023
# NOVEMBER 19, 2023
# NOVEMBER 20, 2023
# NOVEMBER 19, 2023
# NOVEMBER 20, 2023
# NOVEMBER 19, 2023
# NOVEMBER 20, 2023
# NOVEMBER 19, 2023
# NOVEMBER 20, 2023
# NOVEMBER 19, 2023
# NOVEMBER 19, 2023
# NOVEMBER 18, 2023
# NOVEMBER 18, 2023
# NOVEMBER 18, 2023
# NOVEMBER 17, 2023
# NOVEMBER 16, 2023
# November 18, 2023
# November 27, 2023
# Error getting location from NGCP POWER INTERRUPTION ​ Substation:
 2023
# Error getting location from NGCP POWER INTERRUPTION ​ Substation: Polangui - All Feeders Date: September 23, 2023 (Sat) Time: ​ 9:00 AM - 9:10 AM Reason: Momentary power interruption requested by Gallintina Industria Corporacion to isolate their 69kV line.  Time: ​ 4:50 PM - 5:00 PM Reason: Momentary power interruption to facilitate reconnection of Gallintina Industria Corporacion.: 'str' object has no attribute 'findall'
# --- False
# September 22, 2023
# September 19, 2023
# September 19, 2023
# September 22, 2023
# September 24, 2023
# Error getting location from NGCP POWER INTERRUPTION ​ Substation: Tabaco - All Feeders               Malinao - All Feeders Date: September 24, 2023 (Sunday) Time: ​ 6:00 AM to 6:00 PM Reason: To conduct line and substation maintenance activities: 'str' object has no attribute 'findall'
# --- False
# September 18, 2023
# September 18, 2023
# September 16, 2023
# September 15, 2023
# September 15, 2023
# September 15, 2023
# September 14, 2023
# SEPTEMBER 15, 2023
# SEPTEMBER 13, 2023
# September 12, 2023
# September 09, 2023
# September 09, 2023
# September 09, 2023
# September 08, 2023
# September 08, 2023
# September 08, 2023
# September 9, 2023
# September 8, 2023 Time: 5:00 AM to 6:00 AM / 2:00 PM to 3:00 PM Reason: Momentary shutdown request by Phil. Hydro for the isolation & reconnection of Phil. Hydro Plant to facilitate substation maintenance activities  Substation: Sta. Misericordia Feeders 1 & 2 Date: September 10, 2023
# Error getting date from NGCP POWER INTERRUPTION  Substation: Sta. Misericordia Feeders 1 & 2 Date: September 8, 2023 Time: 5:00 AM to 6:00 AM / 2:00 PM to 3:00 PM Reason: Momentary shutdown request by Phil. Hydro for the isolation & reconnection of Phil. Hydro Plant to facilitate substation maintenance activities  Substation: Sta. Misericordia Feeders 1 & 2 Date: September 10, 2023 Time: 5:00 PM to 6:00 PM Reason: Momentary shutdown of Daraga-Sto. Domingo 69 kV line to facilitate load transfer of Daraga-Sorsogon 69 kV line from T01 to T03: unconverted data remains:  Time: 5:00 AM to 6:00 AM / 2:00 PM to 3:00 PM Reason: Momentary shutdown request by Phil. Hydro for the isolation & reconnection of Phil. Hydro Plant to facilitate substation maintenance activities  Substation: Sta. Misericordia Feeders 1 & 2 Date: September 10, 2023
# --- September 8, 2023 Time: 5:00 AM to 6:00 AM / 2:00 PM to 3:00 PM Reason: Momentary shutdown request by Phil. Hydro for the isolation & reconnection of Phil. Hydro Plant to facilitate substation maintenance activities  Substation: Sta. Misericordia Feeders 1 & 2 Date: September 10, 2023
# Error getting location from NGCP POWER INTERRUPTION  Substation: Sta. Misericordia Feeders 1 & 2 Date: September 8, 2023 Time: 5:00 AM to 6:00 AM / 2:00 PM to 3:00 PM Reason: Momentary shutdown request by Phil. Hydro for the isolation & reconnection of Phil. Hydro Plant to facilitate substation maintenance activities  Substation: Sta. Misericordia Feeders 1 & 2 Date: September 10, 2023 Time: 5:00 PM to 6:00 PM Reason: Momentary shutdown of Daraga-Sto. Domingo 69 kV line to facilitate load transfer of Daraga-Sorsogon 69 kV line from T01 to T03: 'str' object has no attribute 'findall'
# --- False
# September 8, 2023
# September 07, 2023
# September 7, 2023
# September 6, 2023
# September 04, 2023
# September 04, 2023
# September 03, 2023
# September 02, 2023
# September 02, 2023
# September 2, 2023
# September 3, 2023
# September 2, 2023
# AUGUST 31, 2023
# August 30, 2023
# AUGUST 30, 2023
# August 28, 2023
# August 25, 2023
