# %%
from datetime import datetime
import unicodedata
import ast
import emoji
import pandas as pd
import re

def normalize_line(line: str):
    try:
        string = ast.literal_eval(line).decode()
    except Exception:
        string = ''
    no_endline = string.replace('\n', ' ')
    no_unicode_letters = unicodedata.normalize('NFKC', no_endline)
    no_emoji = emoji.replace_emoji(no_unicode_letters, replace='')

    return no_emoji

def try_regex(reg, string, todo):
    res = reg.findall(string)
    if len(res) > 0:
        try:
            return todo(res[0])
        except Exception as e:
            print(res, e)
            return False
    return False

def process_batanelco_file(file_path):
    data = { 'date': [], 'location': [], 'type': [] }
    df = pd.DataFrame(data)
    
    date_regex = re.compile("DATE: .*\, 202.")
    try:
        with open(file_path, 'r') as f:
            for line in f:
                normalized = normalize_line(line)
                if 'power interruption' not in normalized: continue
                    
                try:
                    date_str = try_regex(date_regex, normalized, lambda x: x[6:])
                    if not date_str:
                        date_str = try_regex(re.compile(", .*, 202.,"), normalized, lambda x: x[2:-1])
                    if not date_str:
                        date_str = try_regex(re.compile("DATE: .* 202."), normalized, lambda x: x[6:])
                    if not date_str:
                        date_str = try_regex(re.compile("DATE:.* 202."), normalized, lambda x: x[5:])
                    if not date_str:
                        date_str = try_regex(re.compile("Date: .* 202."), normalized, lambda x: x[6:])
                    if not date_str:
                        date_str = try_regex(re.compile("Date:.* 202."), normalized, lambda x: x[5:])
                    
                    print(date_str)
                    date = datetime.strptime(date_str, "%B %d, %Y")
                except Exception as e:
                    print(f"Error getting date from {normalized}: {e}")
                    print("---", date_str)
                    
                try:
                    location_str = try_regex(re.compile("Area: .* Time:"), normalized, lambda x: x[6:-5])
                    if not location_str:
                        location_str = try_regex(re.compile("\) .*:"), normalized, lambda x: x[2:-1])
                    if not location_str:
                        location_str = try_regex(re.compile("\)  .*:"), normalized, lambda x: x[3:-1])
                    if not location_str:
                        location_str = try_regex(re.compile("\)  .* Time:"), normalized, lambda x: x[3:-5])
                    
                    location = location_str
                    
                    print(date, location)
                    
                    type = 'BATANELCO'
                    row_df = pd.DataFrame([[date, location, type]], columns=df.columns)
                    df = pd.concat([row_df, df], ignore_index=True)
                except Exception as e:
                    print(f"Error getting location from {normalized}: {e}")
                    print("---", location_str)
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        
    return df
        
res = process_batanelco_file('BATANELCO_public_2.txt')
res.to_csv('data.csv', index=False, header=False, mode='a')
# Out:
# March 15, 2024
# 2024-03-15 00:00:00  Vahangsion Time: 8:00 AM - 12
# March 15, 2024
# 2024-03-15 00:00:00 Mun. Of Itbayat Time: 5:00 AM - 8
# False
# Error getting date from POWER INTERRUPTION ADVISORY  A 20-minute power interruption affecting South Feeder (Chanarian-Tukon, Mahatao, Ivana, and Uyugan) will occur anytime from now to repair / replace primary jumper wire in Tukon.  Sorry for the inconvenience. Thank you for bearing with us.: strptime() argument 1 must be str, not bool
# --- False
# 2024-03-15 00:00:00 False
# The scheduled power interruption in Itbayat on Friday, March 8, 2024
# Error getting date from UPDATE: The scheduled power interruption in Itbayat on Friday, March 8, 2024, is now POSTPONED until further notice. We'll keep you posted on the new schedule. Thank you!: time data 'The scheduled power interruption in Itbayat on Friday, March 8, 2024' does not match format '%B %d, %Y'
# --- The scheduled power interruption in Itbayat on Friday, March 8, 2024
# 2024-03-15 00:00:00 False
# March 8, 2024
# 2024-03-08 00:00:00 Mun. Of Itbayat Time: 8:00 AM - 5
# March 7, 2024 (Thursday) Mun. Of Uyugan Time: 8:00 AM - 12:00 PM  Kayva-Uyugan Time: 8:00 AM - 5:00 PM  Date: March 8, 2024
# Error getting date from To our Valued Member-Consumer Owners,  Please be informed of the following schedule of power interruption:  Date: March 7, 2024 (Thursday) Mun. Of Uyugan Time: 8:00 AM - 12:00 PM  Kayva-Uyugan Time: 8:00 AM - 5:00 PM  Date: March 8, 2024 (Friday) Mun. Of Basco Time: 3:00 AM - 8:00 AM  Thank you for bearing with us.: unconverted data remains:  (Thursday) Mun. Of Uyugan Time: 8:00 AM - 12:00 PM  Kayva-Uyugan Time: 8:00 AM - 5:00 PM  Date: March 8, 2024
# --- March 7, 2024 (Thursday) Mun. Of Uyugan Time: 8:00 AM - 12:00 PM  Kayva-Uyugan Time: 8:00 AM - 5:00 PM  Date: March 8, 2024
# 2024-03-08 00:00:00 Mun. Of Uyugan Time: 8:00 AM - 12:00 PM  Kayva-Uyugan Time: 8:00 AM - 5:00 PM  Date: March 8, 2024 (Friday) Mun. Of Basco Time: 3:00 AM - 8
# March 1, 2024
# 2024-03-01 00:00:00 Time: 8:00 AM - 12
# February 23, 2024
# 2024-02-23 00:00:00 Time: 6:00 AM - 9
# February 18, 2024
# 2024-02-18 00:00:00 Time: 7:00 AM - 5
# False
# Error getting date from November 8, 2023 - Sa katatapos lang na radio guesting ng Batanelco sa Radyo Pilipinas Batanes ay tinalakay ang R.A. 11552 AN ACT EXTENDING AND ENHANCING THE IMPLEMENTATION OF THE LIFELINE RATE, AMENDING FOR THE PURPOSE, SECTION 73 OF THE REPUBLIC ACT NO. 9136, OTHERWISE KNOWN AS THE "ELECTRIC POWER INDUSTRY REFORM ACT OF 2001 AS AMENDED BY REPUBLIC ACT NO. 10150"  Ang Lifeline Rate ay tumutukoy sa subsidized na rate o diskwento na ibinibigay sa mga kwalipikadong marginalized end-users.   Ang Lifeline Discount ay isang non-cash monetary discount na ilalapat ng distribution utility sa buwanang singil sa kuryente ng mga kwalipikadong residential consumers.  Ang diskusyon ay pinangunahan ng Institutional Services Department (ISD) na nilahukan nila Ms. Marilys G. Ponce, ISD Manager at Ms. Syra Valiente, Information Officer bilang mga tagapagsalita.   Ang pinaigting na batas na ito ay inaasahang ipapatupad sa January 2024.  Narito ang ibang detalye patungkol sa Lifeline Rate   https://m.facebook.com/story.php?story_fbid=653087616927128&id=100066776862639&mibextid=2JQ9oc  Samantala, ilan din sa mga paksang napag-usapan ay ang patungkol sa district elections at kwalipikasyon ng mga board of directors, disconnection policy, power interruption schedules/ updates at bill payment options.: strptime() argument 1 must be str, not bool
# --- False
# 2024-02-18 00:00:00 na nilahukan nila Ms. Marilys G. Ponce, ISD Manager at Ms. Syra Valiente, Information Officer bilang mga tagapagsalita.   Ang pinaigting na batas na ito ay inaasahang ipapatupad sa January 2024.  Narito ang ibang detalye patungkol sa Lifeline Rate   https
# 2023, 12:00 AM  BATAN ISLAND  AREAS WITHOUT ELECTRICITY (KABUAN NU KURYINTI) as reported:  1.Batan Feeder 2/South Feeder affecting Chanarian-Tukon, Mahatao, Ivana and Uyugan since July 25, 2023, 7:09 PM Remarks - Isolated the feeder in anticipation of stronger effects of typhoon  2.Ivatan Lodge Distribution Transformer affecting some parts of Brgy. Kaychanarianan, Basco since July 25, 2023, 7:15 PM Remarks - Restoration not yet possible due to typhoon  Remarks - Batan Feeder 1 affecting most of Basco's barangays (except for Ivatan Lodge DT) is still with power  SABTANG ISLAND Not yet confirmed as of July 26, 2023
# Error getting date from BATANELCO POWER SITUATION UPDATE as of July 26, 2023, 12:00 AM  BATAN ISLAND  AREAS WITHOUT ELECTRICITY (KABUAN NU KURYINTI) as reported:  1.Batan Feeder 2/South Feeder affecting Chanarian-Tukon, Mahatao, Ivana and Uyugan since July 25, 2023, 7:09 PM Remarks - Isolated the feeder in anticipation of stronger effects of typhoon  2.Ivatan Lodge Distribution Transformer affecting some parts of Brgy. Kaychanarianan, Basco since July 25, 2023, 7:15 PM Remarks - Restoration not yet possible due to typhoon  Remarks - Batan Feeder 1 affecting most of Basco's barangays (except for Ivatan Lodge DT) is still with power  SABTANG ISLAND Not yet confirmed as of July 26, 2023, 12:00 AM; Though, no power interruption was reported from the last update at 9:00 PM, July 25, 2023  ITBAYAT ISLAND 1.Kumayasakas Water Pump was isolated (manually off) at 11:40 PM, July 25, 2023 due to strong winds  Remarks - the rest of Itbayat Island is under Normal Power Operation: time data "2023, 12:00 AM  BATAN ISLAND  AREAS WITHOUT ELECTRICITY (KABUAN NU KURYINTI) as reported:  1.Batan Feeder 2/South Feeder affecting Chanarian-Tukon, Mahatao, Ivana and Uyugan since July 25, 2023, 7:09 PM Remarks - Isolated the feeder in anticipation of stronger effects of typhoon  2.Ivatan Lodge Distribution Transformer affecting some parts of Brgy. Kaychanarianan, Basco since July 25, 2023, 7:15 PM Remarks - Restoration not yet possible due to typhoon  Remarks - Batan Feeder 1 affecting most of Basco's barangays (except for Ivatan Lodge DT) is still with power  SABTANG ISLAND Not yet confirmed as of July 26, 2023" does not match format '%B %d, %Y'
# --- 2023, 12:00 AM  BATAN ISLAND  AREAS WITHOUT ELECTRICITY (KABUAN NU KURYINTI) as reported:  1.Batan Feeder 2/South Feeder affecting Chanarian-Tukon, Mahatao, Ivana and Uyugan since July 25, 2023, 7:09 PM Remarks - Isolated the feeder in anticipation of stronger effects of typhoon  2.Ivatan Lodge Distribution Transformer affecting some parts of Brgy. Kaychanarianan, Basco since July 25, 2023, 7:15 PM Remarks - Restoration not yet possible due to typhoon  Remarks - Batan Feeder 1 affecting most of Basco's barangays (except for Ivatan Lodge DT) is still with power  SABTANG ISLAND Not yet confirmed as of July 26, 2023
# 2024-02-18 00:00:00 as reported:  1.Batan Feeder 2/South Feeder affecting Chanarian-Tukon, Mahatao, Ivana and Uyugan since July 25, 2023, 7:09 PM Remarks - Isolated the feeder in anticipation of stronger effects of typhoon  2.Ivatan Lodge Distribution Transformer affecting some parts of Brgy. Kaychanarianan, Basco since July 25, 2023, 7:15 PM Remarks - Restoration not yet possible due to typhoon  Remarks - Batan Feeder 1 affecting most of Basco's barangays (except for Ivatan Lodge DT) is still with power  SABTANG ISLAND Not yet confirmed as of July 26, 2023, 12:00 AM; Though, no power interruption was reported from the last update at 9:00 PM, July 25, 2023  ITBAYAT ISLAND 1.Kumayasakas Water Pump was isolated (manually off) at 11
# 2023, 12:00 AM  BATAN ISLAND  AREAS WITHOUT ELECTRICITY (KABUAN NU KURYINTI) as reported:  1.Batan Feeder 2/South Feeder affecting Chanarian-Tukon, Mahatao, Ivana and Uyugan since July 25, 2023, 7:09 PM Remarks - Isolated the feeder in anticipation of stronger effects of typhoon  2.Ivatan Lodge Distribution Transformer affecting some parts of Brgy. Kaychanarianan, Basco since July 25, 2023, 7:15 PM Remarks - Restoration not yet possible due to typhoon  Remarks - Batan Feeder 1 affecting most of Basco's barangays (except for Ivatan Lodge DT) is still with power  SABTANG ISLAND Not yet confirmed as of July 26, 2023
# Error getting date from BATANELCO POWER SITUATION UPDATE as of July 26, 2023, 12:00 AM  BATAN ISLAND  AREAS WITHOUT ELECTRICITY (KABUAN NU KURYINTI) as reported:  1.Batan Feeder 2/South Feeder affecting Chanarian-Tukon, Mahatao, Ivana and Uyugan since July 25, 2023, 7:09 PM Remarks - Isolated the feeder in anticipation of stronger effects of typhoon  2.Ivatan Lodge Distribution Transformer affecting some parts of Brgy. Kaychanarianan, Basco since July 25, 2023, 7:15 PM Remarks - Restoration not yet possible due to typhoon  Remarks - Batan Feeder 1 affecting most of Basco's barangays (except for Ivatan Lodge DT) is still with power  SABTANG ISLAND Not yet confirmed as of July 26, 2023, 12:00 AM; Though, no power interruption was reported from the last update at 9:00 PM, July 25, 2023  ITBAYAT ISLAND 1.Kumayasakas Water Pump was isolated (manually off) at 11:40 PM, July 25, 2023 due to strong winds  Remarks - the rest of Itbayat Island is under Normal Power Operation: time data "2023, 12:00 AM  BATAN ISLAND  AREAS WITHOUT ELECTRICITY (KABUAN NU KURYINTI) as reported:  1.Batan Feeder 2/South Feeder affecting Chanarian-Tukon, Mahatao, Ivana and Uyugan since July 25, 2023, 7:09 PM Remarks - Isolated the feeder in anticipation of stronger effects of typhoon  2.Ivatan Lodge Distribution Transformer affecting some parts of Brgy. Kaychanarianan, Basco since July 25, 2023, 7:15 PM Remarks - Restoration not yet possible due to typhoon  Remarks - Batan Feeder 1 affecting most of Basco's barangays (except for Ivatan Lodge DT) is still with power  SABTANG ISLAND Not yet confirmed as of July 26, 2023" does not match format '%B %d, %Y'
# --- 2023, 12:00 AM  BATAN ISLAND  AREAS WITHOUT ELECTRICITY (KABUAN NU KURYINTI) as reported:  1.Batan Feeder 2/South Feeder affecting Chanarian-Tukon, Mahatao, Ivana and Uyugan since July 25, 2023, 7:09 PM Remarks - Isolated the feeder in anticipation of stronger effects of typhoon  2.Ivatan Lodge Distribution Transformer affecting some parts of Brgy. Kaychanarianan, Basco since July 25, 2023, 7:15 PM Remarks - Restoration not yet possible due to typhoon  Remarks - Batan Feeder 1 affecting most of Basco's barangays (except for Ivatan Lodge DT) is still with power  SABTANG ISLAND Not yet confirmed as of July 26, 2023
# 2024-02-18 00:00:00 as reported:  1.Batan Feeder 2/South Feeder affecting Chanarian-Tukon, Mahatao, Ivana and Uyugan since July 25, 2023, 7:09 PM Remarks - Isolated the feeder in anticipation of stronger effects of typhoon  2.Ivatan Lodge Distribution Transformer affecting some parts of Brgy. Kaychanarianan, Basco since July 25, 2023, 7:15 PM Remarks - Restoration not yet possible due to typhoon  Remarks - Batan Feeder 1 affecting most of Basco's barangays (except for Ivatan Lodge DT) is still with power  SABTANG ISLAND Not yet confirmed as of July 26, 2023, 12:00 AM; Though, no power interruption was reported from the last update at 9:00 PM, July 25, 2023  ITBAYAT ISLAND 1.Kumayasakas Water Pump was isolated (manually off) at 11
# False
# Error getting date from POWER SITUATION ADVISORY  Para sa impormasyon ng Member-Consumer-Owners sa Sabtang Island:  Ang madalas na power interruption / brownout na nararanasan ngayon ay dulot ng sea spray (sanisi) contamination sa overhead tie line at switchyard ng NPC dala ng sama ng panahon. Kapag kontaminado ang mga pang-elektrikal na linya, insulators at iba pang pasilidad, nagaganap ang 'electrical arcing' o 'arc flash' kung saan nagkaroon ng panibagong daluyan ng kuryente na hindi kanais-nais at ito ay nagiging sanhi ng pagkawala ng kuryente.  Kasalukuyang nagsasagawa ng inspeksyon at pagsasaayos ang NPC upang maibalik ang serbisyo ng kuryente. Maraming salamat sa inyong pang unawa.: strptime() argument 1 must be str, not bool
# --- False
# 2024-02-18 00:00:00 False
# False
# Error getting date from A sudden power interruption at 6:35PM affected Batan Feeder 1 (Brgy. Kaychanarianan, Kayhuvokan, Kayvaluganan, San Antonio and San Joaquin) while in restoration of the previously announced emergency servicing for Kayvaluganan and San Joaquin only. Restoration is ongoing.: strptime() argument 1 must be str, not bool
# --- False
# 2024-02-18 00:00:00 False
# False
# Error getting date from POWER INTERRUPTION ADVISORY  A one-hour power interruption affecting Brgy. Kayvaluganan and Brgy. San Joaquin will be implemented anytime from now due to emergency servicing of facilities at DPWH Riser. Sorry for the inconvenience and thank you for bearing with us.: strptime() argument 1 must be str, not bool
# --- False
# 2024-02-18 00:00:00 False
# False
# Error getting date from Sa mga minamahal naming Member Consumer Owners:  Nais po naming ipaalam sa inyo na ang naka-schedule na Power Interruption po natin bukas January 31, 2023 (Tuesday) ay kanselado.  Makakaasa po kayong amin pong ipopost ang panibagong schedule ng power interruption sa mga apektadong barangay.  Maraming salamat po sa inyong pagunawa.: strptime() argument 1 must be str, not bool
# --- False
# 2024-02-18 00:00:00 False
# False
# Error getting date from POWER UPDATE  Ipinababatid sa lahat ng Member-Consumer-Owners ng Sabtang na nagkaroon ngayon ng emergency power outage upang kumpunihin ang Underground Distribution System (UDS) interconnecting facilities sa Mahat. Inaasahang tatagal ng tatlong (3) oras ang power interruption.  Maraming salamat sa inyong pang-unawa.: strptime() argument 1 must be str, not bool
# --- False
# 2024-02-18 00:00:00 False
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a Scheduled Power Interruption on August 27, 2022 (Saturday)  Whole BATAN Island Time: 4:30 AM - 8:00 AM  Parts of Kayhuvokan Time: 8:00 AM - 5:00 PM  *There will be a 30-minute power interruption at Basco Feeder (Kaychanarianan, Kayhuvokan, Kayvaluganan, San Antonio, San Joaquin) prior to the scheduled activity to isolate the affected lines.  *Upon completion of the activity, there will be a 30-minute power interruption at Basco Feeder to re-install UDS Fuses safely and energize the whole system thereafter.  Thank you for bearing with us.  Stay healthy. Stay safe.: strptime() argument 1 must be str, not bool
# --- False
# 2024-02-18 00:00:00  Whole BATAN Island Time: 4:30 AM - 8:00 AM  Parts of Kayhuvokan Time: 8:00 AM - 5
# False
# Error getting date from There will be an emergency power interruption between 1:00PM to 5:00PM this afternoon in the municipalities of Ivana and Uyugan to safety the UDS Cables affected by DPWH construction. Sorry for the inconvenience and thank you for bearing with us.: strptime() argument 1 must be str, not bool
# --- False
# 2024-02-18 00:00:00 False
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a power interruption in BATAN ISLAND:  APRIL 30, 2022 (SABADO) Time: 6:00 AM - 8:00 AM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe.: strptime() argument 1 must be str, not bool
# --- False
# 2024-02-18 00:00:00 Time: 6:00 AM - 8
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Barangay:  APRIL 21, 2022 (THURSDAY) Area: San Antonio Time: 6:00 AM - 10:00 AM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe.: strptime() argument 1 must be str, not bool
# --- False
# 2024-02-18 00:00:00 San Antonio
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Barangay and municipality:  APRIL 5, 2022 (TUESDAY) Area: DIURA Time: Anytime between           9:00 AM - 3:00 PM  APRIL 6, 2022 (WEDENSDAY) Area: DIURA Time: Anytime between           9:00 AM - 3:00 PM  APRIL 7, 2022 (THURSDAY) Area: IVANA & UYUGAN Time: Anytime between           9:00 AM - 3:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe.: strptime() argument 1 must be str, not bool
# --- False
# 2024-02-18 00:00:00 DIURA Time: Anytime between           9:00 AM - 3:00 PM  APRIL 6, 2022 (WEDENSDAY) Area: DIURA Time: Anytime between           9:00 AM - 3:00 PM  APRIL 7, 2022 (THURSDAY) Area: IVANA & UYUGAN
# March 30, 2022
# 2022-03-30 00:00:00 Time: 8:00 AM - 12
# False
# Error getting date from BANDILLO  Asahan po ang isang oras na power interruption sa South Feeder (Chanarian-Tukon, Mahatao, Ivana and Uyugan) anumang oras ngayong araw. Kaugnay pa rin po ito ng NPC Maintenance.: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-30 00:00:00 False
# March 24, 2022
# 2022-03-24 00:00:00 Time: 2:00 AM - 4
# March 23, 2022
# 2022-03-23 00:00:00  LGU BASCO & SDCBI Date: March 23, 2022 (Wednesday)
# False
# Error getting date from Ipinababatid po sa lahat ng ating mga konsumidores na ang kasalukuyang power interruption (brownout) na nararanasan ng Batan Island ay kaugnay ng NPC Maintenance na nauna nang inanunsyo noong nakaraang linggo. Maraming salamat sa inyong pag-unawa.: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 False
# March 22, 2022 (Tuesday) Time: NO DEFINITE TIME  Sta. Rosa & Sta. Maria Date: March 23-24,2022 (Wednesday, Thursday) Time: NO DEFINITE TIME  Sta. Lucia & San Rafael Date: March 25, 2022
# Error getting date from To our Valued Member-Consumer Owners:  There will be a Unscheduled power interruption in the following Barangay:  San Rafael & Sta. Lucia Date: March 22, 2022 (Tuesday) Time: NO DEFINITE TIME  Sta. Rosa & Sta. Maria Date: March 23-24,2022 (Wednesday, Thursday) Time: NO DEFINITE TIME  Sta. Lucia & San Rafael Date: March 25, 2022 (Friday) Time: NO DEFINITE TIME  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe.: unconverted data remains:  (Tuesday) Time: NO DEFINITE TIME  Sta. Rosa & Sta. Maria Date: March 23-24,2022 (Wednesday, Thursday) Time: NO DEFINITE TIME  Sta. Lucia & San Rafael Date: March 25, 2022
# --- March 22, 2022 (Tuesday) Time: NO DEFINITE TIME  Sta. Rosa & Sta. Maria Date: March 23-24,2022 (Wednesday, Thursday) Time: NO DEFINITE TIME  Sta. Lucia & San Rafael Date: March 25, 2022
# 2022-03-23 00:00:00 Time: NO DEFINITE TIME  Sta. Rosa & Sta. Maria Date: March 23-24,2022 (Wednesday, Thursday) Time: NO DEFINITE TIME  Sta. Lucia & San Rafael Date: March 25, 2022 (Friday) Time
# March 17-29, 2022
# Error getting date from To our Valued Member-Consumer Owners:  There will be a Unscheduled power interruption in the Island of:  BATAN ISLAND Date: March 17-29, 2022 Time: NO DEFINITE TIME  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe.: time data 'March 17-29, 2022' does not match format '%B %d, %Y'
# --- March 17-29, 2022
# 2022-03-23 00:00:00 False
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a Unscheduled power interruption in the Municipality of:  ITBAYAT, BATANES Date: March 17-25,2022 Time: NO DEFINITE TIME  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe.: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 False
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Barangay:  FEBRUARY 23, 2022 (WEDNESDAY) Area: Manaraw, Kayvaluganan Time: 8:00 AM - 5:00 PM  FEBRUARY 26, 2022 (SATURDAY) Area: BATAN ISLAND Time: 7:30 AM - 5:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe.: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 Manaraw, Kayvaluganan Time: 8:00 AM - 5:00 PM  FEBRUARY 26, 2022 (SATURDAY) Area: BATAN ISLAND
# False
# Error getting date from EMERGENCY POWER INTERRUPTION Date/Time off: 02/13/2022, 9:00AM Affected Area(s): Brgy. San Antonio Cause: Replacement of Blacer Transformer (in regard to the power interruption earlier) Date/Time Restored: 02/13/2022, 10:10AM  -------------------------------------------  POWER INTERRUPTION Date/Time Off: 02/13/2022, 8:20AM Affected Area(s): Parts of Brgy. San Antonio Cause: Burnt bushing of Blacer Transformer near DOLE Office  Our Technical Team is currently preparing for the repair. We will keep you posted.  Sorry for the inconvenience and thank you for bearing with us.: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 Date/Time Restored: 02/13/2022, 10:10AM  -------------------------------------------  POWER INTERRUPTION Date/Time Off: 02/13/2022, 8:20AM Affected Area(s): Parts of Brgy. San Antonio Cause
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Municipality and Barangay:  FEBRUARY 10, 2022 (THURSDAY) Area: Ivana & Uyugan Time: 7:00 AM - 12:00 PM  FEBRUARY 11, 2022 (FRIDAY) Area: Salagao Time: 8:00 AM - 12:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe.: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 Ivana & Uyugan Time: 7:00 AM - 12:00 PM  FEBRUARY 11, 2022 (FRIDAY) Area: Salagao
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Barangays:  FEBRUARY 04, 2022 (Friday)   Area: Diptan & Diura Mahatao  Time: 8:00 AM - 12:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 Diptan & Diura Mahatao
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Municipality:  JANUARY 31, 2022 (MONDAY) Area: Ivana & Uyugan Time: 1:30 PM - 4:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe.: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 Ivana & Uyugan
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Barangays:  JANUARY 25, 2022 (Tuesday)   Area: Dita St. & Vahangsion  Time: 8:00 AM - 11:00 AM.  Area : DAR office Sayad Time: 1:00 PM - 4:00 PM  JANUARY 27, 2022 (THURSDAY) Area: Kayvaluganan ( Basco)  Time: 5:00 AM - 12:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 Dita St. & Vahangsion  Time: 8:00 AM - 11:00 AM.  Area : DAR office Sayad Time: 1:00 PM - 4:00 PM  JANUARY 27, 2022 (THURSDAY) Area: Kayvaluganan ( Basco)
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Barangays:  JANUARY 11, 2022 (Tuesday)   Area: Babat Tunga (Basco)   Time: 8:00 AM - 12:00 PM  JANUARY 12, 2022 (Wednesday) Area: Sayid Tunga (Ivana)  Time: 8:00 AM - 5:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 Babat Tunga (Basco)   Time: 8:00 AM - 12:00 PM  JANUARY 12, 2022 (Wednesday) Area: Sayid Tunga (Ivana)
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Barangays:  JANUARY 6, 2022 (THURSDAY)   Area: PNB & DJ Bakery Transformer  Time: 8:00 AM - 11:00 AM  Area: Song-song Uyugan Time: 1:00 PM - 5:00 PM  JANUARY 7, 2022 (FRIDAY) Area: Kayvaluganan (Uyugan) Time: 8:00 AM - 11:00 AM  Area: Tuhel Time: 1:00PM - 5:00PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 PNB & DJ Bakery Transformer  Time: 8:00 AM - 11:00 AM  Area: Song-song Uyugan Time: 1:00 PM - 5:00 PM  JANUARY 7, 2022 (FRIDAY) Area: Kayvaluganan (Uyugan) Time: 8:00 AM - 11:00 AM  Area: Tuhel
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Barangay:  JANUARY 5, 2022 (WEDNESDAY)   Area: Kayvaluganan(Uyugan), Itbud & Imnajbu  Time: 8:00 AM - 5:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 Kayvaluganan(Uyugan), Itbud & Imnajbu
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Barangay & Municipality:  NOVEMBER 17, 2021 (WEDNESDAY)   Area: UYUGAN  Time: 8:00 AM - 12:00 PM  NOVEMBER 19, 2021 (FRIDAY)  Area: BASCO Time: 8:00 AM - 12:00 PM  NOVEMBER 20, 2021 (SATURDAY) Area: Diptan & Diura, Mahatao Time: 8:00 AM - 5:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 UYUGAN  Time: 8:00 AM - 12:00 PM  NOVEMBER 19, 2021 (FRIDAY)  Area: BASCO Time: 8:00 AM - 12:00 PM  NOVEMBER 20, 2021 (SATURDAY) Area: Diptan & Diura, Mahatao
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in WHOLE BATAN ISLAND:  SEPTEMBER 18-19, 2021 (Saturday & Sunday)  Area: BATAN ISLAND  Time: 7:00 AM - 5:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 BATAN ISLAND
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following barangay:  AUGUST 30, 2021 (MONDAY)  Area: Sta. Maria Road, Babat Kayvaluganan  Time: 5:00 AM - 4:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 Sta. Maria Road, Babat Kayvaluganan
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following barangay:  AUGUST 30, 2021 (MONDAY)  Area: Sta. Maria Road, Babat Kayvaluganan  Time: 5:00 AM - 4:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 Sta. Maria Road, Babat Kayvaluganan
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in WHOLE BATAN ISLAND. :  AUGUST 12, 2021 (THURSDAY)   Time: 5:00 AM - 8:00 AM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00   Time: 5:00 AM - 8
# False
# Error getting date from POWER INTERRUPTION UPDATE August 2, 2021, 10:15AM  To our Member-Consumer-Owners:  Please be advised that emergency servicing of our underground distribution system is on-going. Expect sudden/intermittent power interruption especially in the municipalities of Ivana and Uyugan.  We'll update you on the time of restoration as soon as possible.   Sorry for the inconvenience and thank you for bearing with us.  Photo Credits  Francis Ponce: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 False
# False
# Error getting date from To our Member-Consumer-Owners:  As of 7:50 AM, Batan South Feeder Line 1 from MNHS Sectionalizer (Mahatao) to Uyugan is still with no power. This includes the areas of Vatang, Tuhel, Kayva-Uyugan, Itbud & Imnajbu.   Assessment of the cause of power interruption is on-going and we'll update you on the time of restoration as soon as possible.   Sorry for the inconvenience and thank you for bearing with us.: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 False
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Barangay:  JULY 23, 2021 (FRIDAY)   Area: PARTS OF BRGY. KAYHUVOKAN AND KAYVALUGANAN  Time: 8:00 AM - 12:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 PARTS OF BRGY. KAYHUVOKAN AND KAYVALUGANAN
# False
# Error getting date from BANDILLO  Du tatavuh a Member-Consumer-Owners du Itbayat:  Ipangaxes namen pa su rakux a pasinsya kanu konsiderasyon u nakabigla nu power interruption ta katihay humanam su sivug awi a nabnek a schedule. Niyaya am makayamot du kayen nu di natanggar a problema ta ru linya.  Ichahakey namen pa ipatunyi dimiyu ta aran miyan u schedule nu power interruption ta am maparing a mabliblis du ni estimate awi  a oras depende du kahawan, sirsirbyen ah kanu kadwan pa sira a di ta matanggar a mapaparing a mangailangan su kapi emergency off su power para du safety a niya su dahilan nu ka di namen maparahpit siya dimiyu su antimanu.  Akdawen namen pa u adan a konsiderasyon nyu du ka atu ta umpiring siya u pipaypapyan nu serbisyo nu kuryinti ta.  Dios mamaxes!  Nu umanib dimiyu, Opisina nu Batanelco: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 False
# False
# Error getting date from UPDATE: Power in Basco completely restored at 10:20PM.  UPDATE: Power interruption may take 45 mins.  Power interruption at 9:30PM affecting Basco Feeder (Kaychanarianan, Kayhuvokan, Kayvaluganan, San Antonio, San Joaquin) was due to emergency servicing of BGH Sectionalizer. We'll keep you posted on the duration of the power interruption.   Sorry for the inconvenience and please bear with us.: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 False
# False
# Error getting date from UPDATE: Power restored at 3:45PM  Power interruption at 3:12PM affecting South Feeder (Chanarian-Tukon, Mahatao, Ivana, & Uyugan) was due to overhead fault involving an insulator in Mahatao area. Our linemen are on the way to conduct repair. We'll keep you posted on the duration of the power interruption.: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 False
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Barangay and Municipality:  *JUNE 3, 2021 (Thursday)   Area: Babat Distribution  Time: 5:00 AM - 12:00 PM  *JUNE 4, 2021 (Friday)   Area: Mahatao, Ivana, Uyugan  Time: 5:00 AM - 7:00 AM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 Babat Distribution  Time: 5:00 AM - 12:00 PM  *JUNE 4, 2021 (Friday)   Area: Mahatao, Ivana, Uyugan
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Municipalities:  *MAY 29, 2021 (Saturday)   Area: MAHATAO, IVANA, UYUGAN  Time: 4:00 AM - 8:00 AM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 MAHATAO, IVANA, UYUGAN
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the Barangay of:  *MAY 26, 2021 (Wednesday)   Area: Parts of Kachanarianan  Time: 5:00 AM - 7:00 AM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 Parts of Kachanarianan
# False
# Error getting date from To our Valued Member-Consumer Owners:  There will be a scheduled power interruption in the following Barangays:  *APRIL 15, 2021 (Thursday)   Area: IMNAJBU  Time: 6:00 AM - 8:00 AM   Area: SAN JOAQUIN   Time: 8:00 AM - 11:00 AM  *APRIL 16, 2021 (Friday)  Area: ITBUD Time: 8:00 AM - 4:00 PM  Thank you for bearing with us.  Stay healthy. Stay home. Stay safe: strptime() argument 1 must be str, not bool
# --- False
# 2022-03-23 00:00:00 IMNAJBU  Time: 6:00 AM - 8:00 AM   Area: SAN JOAQUIN   Time: 8:00 AM - 11:00 AM  *APRIL 16, 2021 (Friday)  Area: ITBUD
