# %%
from datetime import datetime
import unicodedata
import ast
import emoji
import pandas as pd
import re

def normalize_line(line: str):
    try:
        string = ast.literal_eval(line).decode()
    except Exception:
        string = ''
    no_endline = string.replace('\n', ' ')
    no_unicode_letters = unicodedata.normalize('NFKC', no_endline)
    no_emoji = emoji.replace_emoji(no_unicode_letters, replace='')

    return no_emoji

def try_regex(reg, string, todo):
    res = reg.findall(string)
    if len(res) > 0:
        try:
            return todo(res[0])
        except Exception as e:
            print(res, e)
            return False
    return False

def process_iselcoii_file(file_path):
    data = { 'date': [], 'location': [], 'type': [] }
    df = pd.DataFrame(data)

    date_regex = re.compile("DATE(?: and TIME)?:.* REASON")
    date_regex2 = re.compile("DATE(?: AND TIME)?:.* REASON")
    location_regex = re.compile("AFFECTED AREAS?: .*All works")
    location_regex2 = re.compile("AFFECTED AREAS?: .*Power wil")
    try:
        with open(file_path, 'r') as f:
            for line in f:
                normalized = normalize_line(line)

                if '!!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!!' not in normalized:
                    continue

                try:
                    date_str = try_regex(date_regex, normalized, lambda x: x[:-7].split(':', maxsplit=1)[1].strip())
                    if not date_str:
                        date_str = try_regex(date_regex2, normalized, lambda x: x[:-7].split(':', maxsplit=1)[1].strip())
                    if not date_str:
                        date_str = try_regex(re.compile("DATE and TIME:.* Reason"), normalized, lambda x: x[:-7].split(':', maxsplit=1)[1].strip())
                    x=None
                    if '-' in date_str:
                        date = date_str.split('-')[0].strip()
                    elif '|' in date_str:
                        date = date_str.split('|')[0].strip()
                    elif ' at ' in date_str:
                        date = date_str.split(' at ')[0].strip()
                    elif 'am' in date_str.lower() or 'pm' in date_str.lower():
                        x = date 
                        date = " ".join(date_str.split(" ")[:3]).strip()
                    date = datetime.strptime(date, "%B %d, %Y")
                except Exception as e:
                    print(f"Error getting date from {normalized}: {e}")
                    print("---", date_str, x)
                
                try:
                    try:
                        location_str = location_regex.findall(normalized)[0][15:-9].strip()
                    except Exception:
                        location_str = location_regex2.findall(normalized)[0][15:-9].strip()
                    if ';' in location_str:
                        locations = location_str.split(';')
                    elif '•' in location_str:
                        locations = location_str.split('•')
                    elif ',' in location_str:
                        locations = location_str.split(',')
                    else:
                        locations = location_str.split('  ')
                    
                    type = 'ISELCOII'

                    for location in locations:
                        if not location:
                            continue
                        row_df = pd.DataFrame([[date, location, type]], columns=df.columns)
                        df = pd.concat([row_df, df], ignore_index=True)

                except Exception as e:
                    print(f"Error getting location from {normalized}: {e}")

    except Exception as e:
        print(f"Error processing {file_path}: {e}")
    return df

# %%
process_iselcoii_file('ISELCOII.txt')
# Out:
# Error getting location from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!!   DATE AND TIME: March 14, 2024 at 8:40 am   REASON: Feeder 3 line Tripped at NGCP ILAGAN  AFFECTED AREAS: Feeder 3  Parts of the Municipality of Ilagan  Portion of Baligatan Alibagu Namnama Salindingan Gayong gayong norte Bigao Siffu  Municipality of Gamu  Parts of the Municipality of Naguilian Magsaysay Portion of San Manuel (Near Guibang)  Parts of the Municipality of Burgos  Raniag  San Bonifacio San Miguel Sitio Duco San Roque  Sitio Singson  *For your information and guidance*  *Power service may be restored upon completion of maintenance. For your safety, always consider our lines energized.  **Please do not copy or download photos containing information about public interest like power interruption,billing,etc.then posting it on your timeline.That information may be changed or updated without notice . So Pleases just click the SHARE button .Thank you.***: list index out of range
# Error getting location from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!!   DATE AND TIME:        March 08, 2024 | 4:26am   REASON:       Feeder 3 line Tripped at NGCP ILAGAN   AFFECTED AREAS:  Municipality of Gamu  Parts of the Municipality of Ilagan • Portion of Baligatan • Alibagu • Namnama • Salindingan • Gayong gayong norte • Bigao • Siffu    Parts of the Municipality of Burgos • Raniag  • San Bonifacio • San Miguel • Sitio Duco • San Roque  • Sitio  Singson   Parts of the Municipality of Naguilian • Magsaysay, Portion of San Manuel (Near Guibang)  *For your information and guidance* *Power service may be restored  upon completion of maintenance. For your safety, always consider our lines energized.  **Please do not copy or download photos containing information about public interest like power interruption,billing,etc.then posting it on your timeline.That information may be changed or updated without notice . So Pleases just click the SHARE button .Thank you.***  #UnscheduledpowerInterruption #ISELCO2: list index out of range
# Error getting location from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!!   DATE AND TIME:        March 06, 2024 at  3:26 pm   REASON:       Feeder 3 line Tripped at NGCP ILAGAN   AFFECTED AREAS:  Municipality of Gamu  Parts of the Municipality of Ilagan • Portion of Baligatan • Alibagu • Namnama • Salindingan • Gayong gayong norte • Bigao • Siffu    Parts of the Municipality of Burgos • Raniag  • San Bonifacio • San Miguel • Sitio Duco • San Roque  • Sitio  Singson   Parts of the Municipality of Naguilian • Magsaysay, Portion of San Manuel (Near Guibang)  *For your information and guidance* *Power service may be restored  upon completion of maintenance. For your safety, always consider our lines energized.  **Please do not copy or download photos containing information about public interest like power interruption,billing,etc.then posting it on your timeline.That information may be changed or updated without notice . So Pleases just click the SHARE button .Thank you.***  #UnscheduledpowerInterruption #ISELCO2: list index out of range
# Error getting location from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!!   DATE AND TIME: February 13, 2024 Tuesday 8:14 pm  REASON: Feeder 3 line Tripped at NGCP ILAGAN  AFFECTED AREAS: Feeder 3  Parts of the Municipality of Ilagan  Portion of Baligatan Alibagu Namnama Salindingan Gayong gayong norte Bigao Siffu  Municipality of Gamu Parts of the Municipality of Naguilian Magsaysay Portion of San Manuel (Near Guibang) Parts of the Municipality of Burgos Raniag  San Bonifacio San Miguel Sitio Duco San Roque  Sitio Singson  *For your information and guidance*  *Power service may be restored upon completion of maintenance. For your safety, always consider our lines energized.  **Please do not copy or download photos containing information about public interest like power interruption,billing,etc.then posting it on your timeline.That information may be changed or updated without notice . So Pleases just click the SHARE button .Thank you.***: list index out of range
# Error getting date from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!!   DATE AND TIME: December 25, 2023  (Monday at 5:56 pm)  REASON: Feeder 3 line Tripped at NGCP ILAGAN  AFFECTED AREAS: Feeder 3  Parts of the Municipality of Ilagan  Portion of Baligatan Alibagu Namnama Salindingan Gayong gayong norte Bigao Siffu  Municipality of Gamu Parts of the Municipality of Naguilian Magsaysay Portion of San Manuel (Near Guibang) Parts of the Municipality of Burgos Raniag  San Bonifacio San Miguel Sitio Duco San Roque  Sitio Singson  *For your information and guidance*  *Power service may be restored upon completion of maintenance. For your safety, always consider our lines energized.  **Please do not copy or download photos containing information about public interest like power interruption,billing,etc.then posting it on your timeline.That information may be changed or updated without notice . So Pleases just click the SHARE button .Thank you.***: unconverted data remains:   (Monday
# --- December 25, 2023  (Monday at 5:56 pm) None
# Error getting location from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!!   DATE AND TIME: December 25, 2023  (Monday at 5:56 pm)  REASON: Feeder 3 line Tripped at NGCP ILAGAN  AFFECTED AREAS: Feeder 3  Parts of the Municipality of Ilagan  Portion of Baligatan Alibagu Namnama Salindingan Gayong gayong norte Bigao Siffu  Municipality of Gamu Parts of the Municipality of Naguilian Magsaysay Portion of San Manuel (Near Guibang) Parts of the Municipality of Burgos Raniag  San Bonifacio San Miguel Sitio Duco San Roque  Sitio Singson  *For your information and guidance*  *Power service may be restored upon completion of maintenance. For your safety, always consider our lines energized.  **Please do not copy or download photos containing information about public interest like power interruption,billing,etc.then posting it on your timeline.That information may be changed or updated without notice . So Pleases just click the SHARE button .Thank you.***: list index out of range
# Error getting date from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!! DATE and TIME October 23, 2023 - Monday 8:00PM REASON: SF6 Circuit Breaker at San Manuel Substation AFFECTED AREAS: • Municipality of Aurora, Isabela • Municipality of San Manuel, Isabela •Parts of Municipality of Burgos, Isabela  Bacnor east  Bacnor West  Catabban  Dalig Viejo •Parts of Municipality Of Cabatuan, Isabela  Portion of Malasin •Parts of Municipality Of Roxas, Isabela San Rafael Matusalem San Antonio Nuesa Bantug Highway Bantug Lintao Bantug Pacoma Bantug 118 Simimbaan All works may be finished ahead of time and power may be possibly restored earlier than scheduled. For Safety purposes, please consider our lines always energized. Power will be restored as soon as the scheduled activities are completed without prior notice. •For your information and guidance.• ••Please do not copy or download photos containing information about public interest like power interruption, billing, etc. then posting it on your timeline. That information may be changed or updated without notice. So, PLEASE just click the SHARE button. Thank you.••• #ISELCO2 #UnscheduledPowerInterruption: argument of type 'bool' is not iterable
# --- False None
# Error getting date from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!!  DATE and TIME: Octoberber 17, 2023 - Tuesday 8:39AM  REASON: Feeder 3 Line Tripped at NGCP Ilagan Substation  AFFECTED AREAS:  Parts of Municipality Ilagan , Isabela  •Baligatan •Alibagu •Namnama •Salindingan •Gayong Gayong Norte •Bigao •Siffu  Parts of Municipality Gamu, Isabela •Upi •District 1 •District 2 •District 3 •Linglingay •Lenzon •Furao •Barcolan •Upi Proper •Mabini •Pintor •Rizal •Buenavista •Dammao •Union •Guibang •Part of Upi (Song Song)  Parts of Municipality Burgos, Isabela •Raniag •San Bonifacio •San Miguel •Sitio Duco •San Roque •Sitio Singson  Parts of Municipality Naguilian, Isabela  •Magsaysay •Part of San Manuel  All works may be finished ahead of time and power may be possibly restored earlier than scheduled. For Safety purposes, please consider our lines always energized. Power will be restored as soon as the scheduled activities are completed without prior notice. •For your information and guidance.• ••Please do not copy or download photos containing information about public interest like power interruption, billing, etc. then posting it on your timeline. That information may be changed or updated without notice. So, PLEASE just click the SHARE button. Thank you.••• #UnScheduledPowerInterruption #ISELCO2: time data 'Octoberber 17, 2023' does not match format '%B %d, %Y'
# --- Octoberber 17, 2023 - Tuesday 8:39AM None
# Error getting location from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!!  DATE and TIME:  September 19, 2023 | Tuesday 8:20PM  REASON: MANUAL LOAD DROPPING DUE TO OVERLOADED SUBSTATION  AFFECTED AREAS:   Parts of Municipality of Burgos  Caliguian (Pob)  San Antonino  Cullalabo Del Norte  Cullalabo Del Sur  Malasin  •For your information and guidance.• ••Please do not copy or download photos containing information about public interest like power interruption, billing, etc. then posting it on your timeline. That information may be changed or updated without notice. So, PLEASE just click the SHARE button. Thank you.••• #UnscheduledPowerInterruption #ISELCO2: list index out of range
# Error getting date from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!!  DATE and TIME August 27, 2023 - Thursday 12:28AM  REASON: SF6 Circuit Breaker at San Manuel Substation  AFFECTED AREAS: • Municipality of Aurora, Isabela • Municipality of San Manuel, Isabela  •Parts of Municipality of Burgos, Isabela  Bacnor east  Bacnor West  Catabban  Dalig Viejo  •Parts of Municipality Of Cabatuan, Isabela  Portion of Malasin  •Parts of Municipality Of Roxas, Isabela San Rafael Matusalem San Antonio Nuesa Bantug Highway Bantug Lintao Bantug Pacoma Bantug 118 Simimbaan  All works may be finished ahead of time and power may be possibly restored earlier than scheduled. For Safety purposes, please consider our lines always energized.  Power will be restored as soon as the scheduled activities are completed without prior notice.  •For your information and guidance.• ••Please do not copy or download photos containing information about public interest like power interruption, billing, etc. then posting it on your timeline. That information may be changed or updated without notice. So, PLEASE just click the SHARE button. Thank you.••• #ISELCO2 #UnscheduledPowerInterruption: argument of type 'bool' is not iterable
# --- False None
# Error getting location from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!!  DATE and TIME: June 23, 2023 - Friday (07:45PM)  REASON: On-going replacement of broken pole Due to Vehicular Accident   Parts of Municipality of Tumauini • Arcon  • Balug  • Bayabo East  • Lalauanan  • Lapogan  • Bantug  • Maligaya  • Minanga  • Paragu  • Sisim Alto   • Sisim Abajo  • Liwanag  • Pilitan   Parts of City of Ilagan • Alinguigan 1st • Alinguigan 2nd  • Alinguigan 3rd  • Ballacong  • Bangag  • Marana 1st  • Marana 2nd  • Marana 3rd  • Minabang  • Morado  • Nanaguan  • Sta. Victoria  • Tangkul  • Binatacan  • Cabisera 10  • Cabisera 14 -16  • Cabisera 25  • Cabisera 27  • Pasa  • Quimalabasa  • Rangayan  • Rugao  • San Andress  • Sindun Bayabo  • Sindun Maride  • Villa Imelda  • Cadu  • Capellan  • Capo  • Fuyo  • Manaring  • San Isidro  • San Juan  • San Lorenzo  • San Pablo  • San Rodrigo  • Santa Catalina  • Sipay   All works may be finished ahead of time and power may be possibly restored earlier than scheduled. For Safety purposes, please consider our lines always energized. Power will be restored as soon as the scheduled activities are completed without prior notice. •For your information and guidance.• ••Please do not copy or download photos containing information about public interest like power interruption, billing, etc. then posting it on your timeline. That information may be changed or updated without notice. So, PLEASE just click the SHARE button. Thank you.••• #ISELCO2: list index out of range
# Error getting date from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!!  DATE and TIME:May 17,2023-Wednesday (8:28 PM)  REASON: feeder 2 line tripped  Update: Energized 9:10PM  AFFECTED AREAS: (Part of City of Ilagan) Baligatan (Portion) Calamagui 2nd Calamagui 1st Osmeña Guinatan San Vicente Naguilian Baculud Sur Naguilian Baculud Norte San Ignacio Sitio Turod Sitio Angeles Centro (Poblacion) Baculud Lullutan Cabannungan 1st Cabannungan 2nd Arusip Sta. Isabel Sur Sta. Isabel Norte Sto. Tomas Sitio San Pedro Sitio Tubo Pilar Bagong Silang Malasin Kakikkikan Sur Kakikkikan Norte Mangcuram Camonatan Sta. Barbara Bagumbayan Sitio Caniogan  All works may be finished ahead of time and power may be possibly restored earlier than scheduled. For Safety purposes, please consider our lines always energized. Power will be restored as soon as the scheduled activities are completed without prior notice.  •For your information and guidance.• ••Please do not copy or download photos containing information about public interest like power interruption, billing, etc. then posting it on your timeline. That information may be changed or updated without notice. So, PLEASE just click the SHARE button. Thank you.••• #ISELCO2: time data 'May 17,2023' does not match format '%B %d, %Y'
# --- May 17,2023-Wednesday (8:28 PM) None
# Error getting date from !!NOTICE OF ISELCO II UNSCHEDULED POWER INTERRUPTION!! DATE and TIME: December 17, 2022 | Saturday 9:02 P.M. REASON:  Feeder 4 Damage Vacuum Circuit Breaker. AFFECTED AREAS: • Municipality of: Roxas Luna Vira Rizal Lanting Lucban Masigun Rang-Ayan San Jose San Luis Bantug • Parts of Municipality of Burgos, Isabela. Caliguian (Pob) Cullalabo Del Norte Cullalabo Del Sur Malasin Masigun San Antonino  December 17, 2022 | Saturday 8:30P.M. REASON: Feeder 2 Damage Vacuum Circuit Breaker. AFFECTED AREAS: • Municipality of: Mallig Quezon Quirino • Parts of Municipality of Roxas Anao Doña Concha Imbiao Muñoz East Muñoz West Quiling San Maros San Pedro San Placido Sinamar Villa Concepcion  All works may be finished ahead of time and power may be possibly restored earlier than scheduled. For Safety purposes, please consider our lines always energized. Power will be restored as soon as the scheduled activities are completed without prior notice. •For your information and guidance.• ••Please do not copy or download photos containing information about public interest like power interruption, billing, etc. then posting it on your timeline. That information may be changed or updated without notice. So, PLEASE just click the SHARE button. Thank you.••• #ISELCO2: unconverted data remains:  | Saturday 9:02 P.M. REASON:  Feeder 4 Damage Vacuum Circuit Breaker. AFFECTED AREAS: • Municipality of: Roxas Luna Vira Rizal Lanting Lucban Masigun Rang
# --- December 17, 2022 | Saturday 9:02 P.M. REASON:  Feeder 4 Damage Vacuum Circuit Breaker. AFFECTED AREAS: • Municipality of: Roxas Luna Vira Rizal Lanting Lucban Masigun Rang-Ayan San Jose San Luis Bantug • Parts of Municipality of Burgos, Isabela. Caliguian (Pob) Cullalabo Del Norte Cullalabo Del Sur Malasin Masigun San Antonino  December 17, 2022 | Saturday 8:30P.M. None
#                      date                                           location  \
# 0     2022-07-13 00:00:00   Parts of City of Ilagan *Brgy. Osmeña *Brgy. ...
# 1     2022-09-08 00:00:00   Parts of Municipality of Roxas, Mallig, and Q...
# 2     2022-09-17 00:00:00                                            Isabela
# 3     2022-09-17 00:00:00                     Isabela Municipality of Quezon
# 4     2022-09-17 00:00:00                             Municipality of Mallig
# ...                   ...                                                ...
# 2137  2024-03-28 00:00:00                                          Aguinaldo
# 2138  2024-03-28 00:00:00                                            Sunlife
# 2139  2024-03-28 00:00:00       Portion of San Manuel (Going to San Mariano)
# 2140  2024-03-28 00:00:00             Parts of the Municipality of Naguilian
# 2141  2024-03-28 00:00:00  Municipality of Benito Soliven Municipality of...
#
#           type
# 0     ISELCOII
# 1     ISELCOII
# 2     ISELCOII
# 3     ISELCOII
# 4     ISELCOII
# ...        ...
# 2137  ISELCOII
# 2138  ISELCOII
# 2139  ISELCOII
# 2140  ISELCOII
# 2141  ISELCOII
#
# [2142 rows x 3 columns]
