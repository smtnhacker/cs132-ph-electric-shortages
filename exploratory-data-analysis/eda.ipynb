# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('data.csv')
df['date'] = pd.to_datetime(df['date'])
df['date'] = pd.to_datetime({
    'year': df['date'].dt.year,
    'month': df['date'].dt.month,
    'day': 1
})

# Filter data for dates within 2022-2023
start_date = pd.Timestamp('2022-01-01')
end_date = pd.Timestamp('2023-12-31')
df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# Aggregate data by date and type, counting entries
aggregated_data = df.groupby(['date', 'type']).size().reset_index(name='count')

# Create a scatter plot
plt.figure(figsize=(10, 6))
for dtype in aggregated_data['type'].unique():
    subset = aggregated_data[aggregated_data['type'] == dtype]
    # plt.scatter(subset['date'], subset['count'], label=dtype)
    plt.plot(subset['date'], subset['count'], label=dtype)

plt.xlabel('Date')
plt.ylabel('Total Count')
plt.title('Total Entries by Date and Type')
plt.legend(title='Type')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.tight_layout()  # Adjust layout to make room for label rotation
plt.show()
# Out:
# C:\Users\Miko\AppData\Local\Temp\ipykernel_26440\604118633.py:5: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load data
df = pd.read_csv('data.csv')
df['date'] = pd.to_datetime(df['date'])
df['date'] = pd.to_datetime({
    'year': df['date'].dt.year,
    'month': df['date'].dt.month,
    'day': 1
})

# Filter data for dates within 2022-2023
start_date = pd.Timestamp('2022-01-01')
end_date = pd.Timestamp('2023-12-31')
df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# Aggregate data by date and type, counting entries
aggregated_data = df.groupby(['date', 'type']).size().reset_index(name='count')

# Create a facet grid
g = sns.FacetGrid(aggregated_data, col='type', col_wrap=2, height=2, aspect=3, sharex=True, sharey=True)
g = g.map(plt.plot, 'date', 'count').add_legend()

plt.subplots_adjust(top=0.9)
g.fig.suptitle('Total Entries by Date and Type')
plt.show()
# Out:
# C:\Users\Miko\AppData\Local\Temp\ipykernel_26440\4177430548.py:7: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])

# %%
df = pd.read_csv('data.csv')
df['date'] = pd.to_datetime(df['date'])
df['date'] = pd.to_datetime({
    'year': df['date'].dt.year,
    'month': df['date'].dt.month,
    'day': 1
})

df = df[(df['type'] == 'MERALCO')]

# Aggregate data by date and type, counting entries
aggregated_data = df.groupby(['date']).size().reset_index(name='count')

# Create a scatter plot
plt.figure(figsize=(10, 6))
# plt.scatter(aggregated_data['date'], aggregated_data['count'], label='MERALCO')
plt.plot(aggregated_data['date'], aggregated_data['count'], label='MERALCO')
plt.xlabel('Date')
plt.ylabel('Total Count')
plt.title('Total Entries by MERALCO over the years')
plt.legend(title='Type')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.tight_layout()  # Adjust layout to make room for label rotation
plt.show()
# Out:
# C:\Users\Miko\AppData\Local\Temp\ipykernel_20792\1007685709.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('data.csv')
df['date'] = pd.to_datetime(df['date'])
df['date'] = pd.to_datetime({
    'year': df['date'].dt.year,
    'month': df['date'].dt.month,
    'day': 1
})

# Filter data for dates within 2022-2023
start_date = pd.Timestamp('2022-01-01')
end_date = pd.Timestamp('2023-12-31')
df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# Aggregate data by date and type, counting entries
unique_locations_per_type = df.groupby('type')['location'].nunique()
aggregated_data = df.groupby(['date', 'type']).size().reset_index(name='count')
aggregated_data['normalized_count'] = aggregated_data.apply(
    lambda row: row['count'] / unique_locations_per_type[row['type']], axis=1)

# Create a scatter plot
plt.figure(figsize=(10, 6))
for dtype in aggregated_data['type'].unique():
    subset = aggregated_data[aggregated_data['type'] == dtype]
    # plt.scatter(subset['date'], subset['normalized_count'], label=dtype)
    plt.plot(subset['date'], subset['normalized_count'], label=dtype)

plt.xlabel('Date')
plt.ylabel('Total Count')
plt.ylim(0, 1.0)
plt.title('Total Entries by Date and Type (Normalized)')
plt.legend(title='Type')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.tight_layout()  # Adjust layout to make room for label rotation
plt.show()
# Out:
# C:\Users\Miko\AppData\Local\Temp\ipykernel_20792\686028822.py:5: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load data
df = pd.read_csv('data.csv')
df['date'] = pd.to_datetime(df['date'])
df['date'] = pd.to_datetime({
    'year': df['date'].dt.year,
    'month': df['date'].dt.month,
    'day': 1
})

# Filter data for dates within 2022-2023
start_date = pd.Timestamp('2022-01-01')
end_date = pd.Timestamp('2023-12-31')
df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# Aggregate data by date and type, counting entries
unique_locations_per_type = df.groupby('type')['location'].nunique()
aggregated_data = df.groupby(['date', 'type']).size().reset_index(name='count')
aggregated_data['normalized_count'] = aggregated_data.apply(
    lambda row: row['count'] / unique_locations_per_type[row['type']], axis=1)

# Create a facet grid
g = sns.FacetGrid(aggregated_data, col='type', col_wrap=2, height=2, aspect=3, sharex=True, sharey=True)
g = g.map(plt.plot, 'date', 'normalized_count').add_legend()

plt.subplots_adjust(top=0.9)
g.fig.suptitle('Total Entries by Date and Type')
plt.show()
# Out:
# C:\Users\Miko\AppData\Local\Temp\ipykernel_26440\1622600366.py:7: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('data.csv')
df['date'] = pd.to_datetime(df['date'])

# Filter data for dates within 2022-2023
start_date = pd.Timestamp('2022-01-01')
end_date = pd.Timestamp('2023-12-31')
df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# Aggregate data by date and type, counting entries
aggregated_data = df.groupby(['date', 'type']).size().reset_index(name='count')
aggregated_data['has_brownout'] = aggregated_data.apply(
    lambda row: 1 if row['count'] else 0, axis=1)

# Create a facet grid
g = sns.FacetGrid(aggregated_data, col='type', col_wrap=1, height=1.5, aspect=12, sharex=True, sharey=True)
g = g.map(plt.scatter, 'date', 'has_brownout').add_legend()

plt.subplots_adjust(top=0.9)
g.fig.suptitle('Total Entries by Date and Type')
plt.show()
# Out:
# C:\Users\Miko\AppData\Local\Temp\ipykernel_26440\1016871774.py:5: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data
df = pd.read_csv('data.csv')
df['date'] = pd.to_datetime(df['date'])
df['date'] = pd.to_datetime({
    'year': df['date'].dt.year,
    'month': df['date'].dt.month,
    'day': 1
})

# Filter data for dates within 2022-2023
start_date = pd.Timestamp('2022-01-01')
end_date = pd.Timestamp('2023-12-31')
df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# Aggregate data by date and type, counting entries
aggregated_data = df.groupby(['date', 'type']).size().reset_index(name='count')

# Pivot the data to have dates as rows and types as columns
pivot_data = aggregated_data.pivot(index='date', columns='type', values='count').fillna(0)

# Calculate standard deviation of each type across time period and sort by it
sorted_types = pivot_data.std().sort_values().index

# Rearrange columns based on sorted types
pivot_data = pivot_data[sorted_types]

# Create a stacked area chart
plt.figure(figsize=(10, 6))
plt.stackplot(pivot_data.index, pivot_data.T, labels=pivot_data.columns, alpha=0.8)

plt.xlabel('Date')
plt.ylabel('Total Count')
plt.title('Total Entries by Date and Type')
plt.legend(title='Type')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.tight_layout()  # Adjust layout to make room for label rotation
plt.show()
# Out:
# C:\Users\Miko\AppData\Local\Temp\ipykernel_12620\1211773403.py:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data
df = pd.read_csv('data.csv')
df['date'] = pd.to_datetime(df['date'])
df['date'] = pd.to_datetime({
    'year': df['date'].dt.year,
    'month': df['date'].dt.month,
    'day': 1
})

# Filter data for dates within 2022-2023
start_date = pd.Timestamp('2022-01-01')
end_date = pd.Timestamp('2023-12-31')
df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# Aggregate data by date and type, counting entries
unique_locations_per_type = df.groupby('type')['location'].nunique()
aggregated_data = df.groupby(['date', 'type']).size().reset_index(name='count')
aggregated_data['normalized_count'] = aggregated_data.apply(
    lambda row: row['count'] / unique_locations_per_type[row['type']], axis=1)

# Pivot the data to have dates as rows and types as columns
pivot_data = aggregated_data.pivot(index='date', columns='type', values='normalized_count').fillna(0)

# Calculate standard deviation of each type across time period and sort by it
sorted_types = pivot_data.std().sort_values().index

# Rearrange columns based on sorted types
pivot_data = pivot_data[sorted_types]

# Create a stacked area chart
plt.figure(figsize=(10, 6))
plt.stackplot(pivot_data.index, pivot_data.T, labels=pivot_data.columns, alpha=0.8)

plt.xlabel('Date')
plt.ylabel('Total Count')
plt.title('Total Entries by Date and Type')
plt.legend(title='Type')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.tight_layout()  # Adjust layout to make room for label rotation
plt.show()
# Out:
# C:\Users\Miko\AppData\Local\Temp\ipykernel_12620\1674175936.py:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])
